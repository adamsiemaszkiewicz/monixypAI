# %% [markdown]
# # Flesh Digressions
# ### Producing Videos from circular loops of the constant and latent layers in StyleGAN2
#
# Besides having the most metal name for a script, this is also a really funway to generate looping videos of a StyleGAN2 model. It creates a loop from the 4x4 constant layer and a loop of the latent space layer (z I assume?) to generate a different feeling looping video.
#
# Credit to [@aydaogman](https://twitter.com/AydaoGMan) for making this script.

# %%
# mount Google Drive on the runtime
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# create a symbolic link to a working directory
# !ln -s /content/gdrive/My\ Drive/Colab\ Notebooks/monixypAI /mydrive

# navigate to the working directory
# %cd /mydrive
# Out:
# /content/gdrive/My Drive/Colab Notebooks/monixypAI

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !git clone https://github.com/dvschultz/stylegan2-ada

# %%
# %cd stylegan2-ada/
# Out:
# /content/gdrive/My Drive/Colab Notebooks/monixypAI/stylegan2-ada

# %% [markdown]
# ## Generate Video
#
# #### Options
# *   `--pkl`: point this to your pkl model file
# *   `--psi`: truncation value
# *   `--radius_large`: how large of a loop the constant layer should be
# *   `--radius_small`: how large of a loop the latent space layer should be
# *   `--step1`: increment step for the constant layer
# *   `--step2`: increment step for the latent space layer
# *   `--video_length`: length of video in circular interpolation (ex. default is 1.0, step2 is 0.0025, so video length is 400 frames)
#
# I recommend starting with all the default values and playing with them from there.

# %%
pkl = '/mydrive/stylegan2-ada/results/00026-monixyp_tfrecords-mirror-mirrory-11gb-gpu-bg-resumecustom/network-snapshot-000068.pkl'

# %%
# !python aydao_flesh_digressions.py --help

# %%
# https://github.com/dvschultz/stylegan2-training

# !python aydao_flesh_digressions.py --pkl $pkl \
#                                    --psi=0.6 \
#                                    --radius_small=10.0 \
#                                    --radius_large=800.00

# circular-30-03-2021-08-53-23-AM.mp4
# !python aydao_flesh_digressions.py --pkl $pkl \
#                                    --psi=0.6 \
#                                    --radius_small=500 \
#                                    --radius_large=10 \
#                                    --seed=123456 \
#                                    --step2=0.002 \
#                                    --video_length=1

# circular-30-03-2021-09-03-49-AM.mp4
# !python aydao_flesh_digressions.py --pkl $pkl \
#                                    --psi=0.6 \
#                                    --radius_small=100 \
#                                    --radius_large=10 \
#                                    --seed=0 \
#                                    --step2=0.002 \
#                                    --video_length=1

# circular-30-03-2021-09-11-28-AM.mp4
# !python aydao_flesh_digressions.py --pkl $pkl \
#                                    --psi=0.6 \
#                                    --radius_small=50 \
#                                    --radius_large=0 \
#                                    --seed=0 \
#                                    --video_length=2

# circular-30-03-2021-09-27-31-AM.mp4
# !python aydao_flesh_digressions.py --pkl $pkl \
#                                    --psi=0.6 \
#                                    --radius_small=0 \
#                                    --radius_large=0 \
#                                    --seed=0 \
#                                    --video_length=2

# circular-30-03-2021-09-34-48-AM.mp4
# !python aydao_flesh_digressions.py --pkl $pkl \
#                                    --psi=0.6 \
#                                    --radius_small=10 \
#                                    --radius_large=0 \
#                                    --seed=0 \
#                                    --video_length=2

# radius_large
# for n in [10, 30, 100, 300]:
#   !python aydao_flesh_digressions.py --pkl $pkl \
#                                     --psi=0.6 \
#                                     --radius_small=10 \
#                                     --radius_large=$n \
#                                     --seed=0 \
#                                     --video_length=2

# radius_small
# for n in [0, 10, 30, 100, 300]:
#   !python aydao_flesh_digressions.py --pkl $pkl \
#                                     --psi=0.6 \
#                                     --radius_small=$n \
#                                     --radius_large=0 \
#                                     --seed=0 \
#                                     --video_length=2

# psi
# for n in [0, 0.1, 0.3, 0.6, 1]:
#   !python aydao_flesh_digressions.py --pkl $pkl \
#                                     --psi=$n \
#                                     --radius_small=30 \
#                                     --radius_large=30 \
#                                     --seed=0 \
#                                     --video_length=2

# step1
# for n in [0, 0.0001, 0.001, 0.01, 0.1, 1]:
  # !python aydao_flesh_digressions.py --pkl $pkl \
  #                                   --psi=0.3 \
  #                                   --radius_small=60 \
  #                                   --radius_large=60 \
  #                                   --seed=0 \
  #                                   --step1=$n \
  #                                   --video_length=2

# step2
# for n in [0.0001, 0.001, 0.01, 0.1, 1]:
#   !python aydao_flesh_digressions.py --pkl $pkl \
#                                     --psi=0.3 \
#                                     --radius_small=60 \
#                                     --radius_large=60 \
#                                     --seed=0 \
#                                     --step2=$n \
#                                     --video_length=2

# circular-01-04-2021-08-41-02-AM.mp4
# !python aydao_flesh_digressions.py --pkl $pkl \
#                                    --psi=0.3 \
#                                    --radius_small=60 \
#                                    --radius_large=60 \
#                                    --seed=666 \
#                                    --video_length=10

# circular-01-04-2021-10-20-19-AM.mp4
# !python aydao_flesh_digressions.py --pkl $pkl \
#                                    --psi=0.3 \
#                                    --radius_small=100 \
#                                    --radius_large=100 \
#                                    --seed=123456 \
#                                    --video_length=10

# circular-01-04-2021-11-00-44-AM.mp4
# !python aydao_flesh_digressions.py --pkl $pkl \
#                                    --psi=0.3 \
#                                    --radius_small=100 \
#                                    --radius_large=30 \
#                                    --seed=123456 \
#                                    --video_length=5

# circular-01-04-2021-11-29-18-AM.mp4
# !python aydao_flesh_digressions.py --pkl $pkl \
#                                    --psi=0.3 \
#                                    --radius_small=30 \
#                                    --radius_large=100 \
#                                    --seed=123456 \
#                                    --video_length=5

# circular-01-04-2021-12-00-35-PM.mp4
# !python aydao_flesh_digressions.py --pkl $pkl \
#                                    --psi=0.3 \
#                                    --radius_small=30 \
#                                    --radius_large=60 \
#                                    --seed=123456 \
#                                    --video_length=5

# circular-01-04-2021-12-29-43-PM.mp4
# !python aydao_flesh_digressions.py --pkl $pkl \
#                                    --psi=0.6 \
#                                    --radius_small=30 \
#                                    --radius_large=60 \
#                                    --seed=123456 \
#                                    --video_length=5

# circular-01-04-2021-12-58-16-PM.mp4
# !python aydao_flesh_digressions.py --pkl $pkl \
#                                    --psi=0.6 \
#                                    --radius_small=10 \
#                                    --radius_large=100 \
#                                    --seed=123456 \
#                                    --video_length=5

# circular-01-04-2021-01-40-23-PM.mp4
# !python aydao_flesh_digressions.py --pkl $pkl \
#                                    --psi=0.6 \
#                                    --radius_small=10 \
#                                    --radius_large=200 \
#                                    --video_length=5

# circular-01-04-2021-02-14-48-PM.mp4
# !python aydao_flesh_digressions.py --pkl $pkl \
#                                    --psi=0.3 \
#                                    --radius_small=10 \
#                                    --radius_large=100 \
#                                    --video_length=5

# circular-01-04-2021-02-47-30-PM.mp4
# !python aydao_flesh_digressions.py --pkl $pkl \
#                                    --psi=0.9 \
#                                    --radius_small=10 \
#                                    --radius_large=100 \
#                                    --video_length=5

# circular-01-04-2021-03-17-19-PM.mp4
# !python aydao_flesh_digressions.py --pkl $pkl \
#                                    --psi=0.75 \
#                                    --radius_small=10 \
#                                    --radius_large=100 \
#                                    --video_length=5

# circular-01-04-2021-03-46-27-PM.mp4
# !python aydao_flesh_digressions.py --pkl $pkl \
#                                    --psi=0.3 \
#                                    --radius_small=10 \
#                                    --radius_large=100 \
#                                    --video_length=5

# circular-01-04-2021-04-15-47-PM.mp4
# !python aydao_flesh_digressions.py --pkl $pkl \
#                                    --psi=0.7 \
#                                    --radius_small=5 \
#                                    --radius_large=120 \
#                                    --video_length=5

# circular-01-04-2021-04-45-49-PM.mp4
# !python aydao_flesh_digressions.py --pkl $pkl \
#                                    --psi=0.7 \
#                                    --radius_small=20 \
#                                    --radius_large=120 \
#                                    --video_length=5

# circular-01-04-2021-04-57-25-PM.mp4
# !python aydao_flesh_digressions.py --pkl $pkl \
#                                    --psi=0.7 \
#                                    --radius_small=30 \
#                                    --radius_large=90 \
#                                    --video_length=2

# circular-01-04-2021-05-06-41-PM.mp4
# !python aydao_flesh_digressions.py --pkl $pkl \
#                                    --psi=0.6 \
#                                    --radius_small=30 \
#                                    --radius_large=90 \
#                                    --video_length=2

# circular-01-04-2021-05-26-42-PM.mp4
# !python aydao_flesh_digressions.py --pkl $pkl \
#                                    --psi=0.6 \
#                                    --radius_small=30 \
#                                    --radius_large=90 \
#                                    --step1=0.001 \
#                                    --video_length=2

# circular-01-04-2021-05-35-49-PM.mp4
# !python aydao_flesh_digressions.py --pkl $pkl \
#                                    --psi=0.6 \
#                                    --radius_small=20 \
#                                    --radius_large=80 \
#                                    --seed=0 \
#                                    --video_length=2

# circular-01-04-2021-06-56-28-PM.mp4
# !python aydao_flesh_digressions.py --pkl $pkl \
#                                    --psi=0.6 \
#                                    --radius_small=20 \
#                                    --radius_large=80 \
#                                    --seed=666 \
#                                    --video_length=10

# circular-02-04-2021-10-06-33-AM.mp4
# !python aydao_flesh_digressions.py --pkl $pkl \
#                                    --psi=0.6 \
#                                    --radius_small=20 \
#                                    --radius_large=80 \
#                                    --seed=666 \
#                                    --step2=0.001 \
#                                    --video_length=1

# circular-02-04-2021-11-29-12-AM.mp4
# !python aydao_flesh_digressions.py --pkl $pkl \
#                                    --psi=0.6 \
#                                    --radius_small=20 \
#                                    --radius_large=80 \
#                                    --seed=666 \
#                                    --step2=0.0005 \
#                                    --video_length=2

# circular-03-04-2021-09-12-20-AM.mp4
# !python aydao_flesh_digressions.py --pkl $pkl \
#                                    --psi=0.6 \
#                                    --radius_small=60 \
#                                    --radius_large=80 \
#                                    --seed=987654321 \
#                                    --video_length=2
# Out:
# Imageio: 'ffmpeg-linux64-v3.3.1' was not found on your computer; downloading it now.
# Try 1. Download from https://github.com/imageio/imageio-binaries/raw/master/ffmpeg/ffmpeg-linux64-v3.3.1 (43.8 MB)
# 45929032/45929032 bytes (100.0%)
#   Done
# File saved as /root/.imageio/ffmpeg/ffmpeg-linux64-v3.3.1.
# Loading networks from "/mydrive/stylegan2-ada/results/00026-monixyp_tfrecords-mirror-mirrory-11gb-gpu-bg-resumecustom/network-snapshot-000068.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Compiling... Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Compiling... Loading... Done.
# Stopping at 2.0 currently at 0.0025
# Stopping at 2.0 currently at 0.005
# Stopping at 2.0 currently at 0.0075
# Stopping at 2.0 currently at 0.01
# Stopping at 2.0 currently at 0.0125
# Stopping at 2.0 currently at 0.015000000000000001
# Stopping at 2.0 currently at 0.0175
# Stopping at 2.0 currently at 0.02
# Stopping at 2.0 currently at 0.0225
# ...
