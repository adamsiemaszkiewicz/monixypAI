# %% [markdown]
# # Flesh Digressions
# ### Producing Videos from circular loops of the constant and latent layers in StyleGAN2
#
# Besides having the most metal name for a script, this is also a really funway to generate looping videos of a StyleGAN2 model. It creates a loop from the 4x4 constant layer and a loop of the latent space layer (z I assume?) to generate a different feeling looping video.
#
# Credit to [@aydaogman](https://twitter.com/AydaoGMan) for making this script.

# %%
# mount Google Drive on the runtime
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# create a symbolic link to a working directory
# !ln -s /content/gdrive/My\ Drive/Colab\ Notebooks/monixypAI /mydrive

# navigate to the working directory
# %cd /mydrive
# Out:
# /content/gdrive/My Drive/Colab Notebooks/monixypAI

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !git clone https://github.com/dvschultz/stylegan2-ada
# Out:
# fatal: destination path 'stylegan2-ada' already exists and is not an empty directory.

# %% [markdown]
# Download a pkl file.

# %%
# !gdown --id 1huJHdsDlj6x50j_uI1wvsIY8zW6O4lVb

# %%
# %cd stylegan2-ada/
# Out:
# /content/gdrive/My Drive/Colab Notebooks/monixypAI/stylegan2-ada

# %% [markdown]
# ## Generate Video
#
# #### Options
# *   `--pkl`: point this to your pkl model file
# *   `--psi`: truncation value
# *   `--radius_large`: how large of a loop the constant layer should be
# *   `--radius_small`: how large of a loop the latent space layer should be
# *   `--step1`: increment step for the constant layer
# *   `--step2`: increment step for the latent space layer
# *   `--video_length`: length of video in circular interpolation (ex. default is 1.0, step2 is 0.0025, so video length is 400 frames)
#
# I recommend starting with all the default values and playing with them from there.

# %%
pkl = '/mydrive/stylegan2-ada/results/00015-monixyp_tfrecords-11gb-gpu-bg-resumecustom/network-snapshot-000120.pkl'

# %%
# !python aydao_flesh_digressions.py --help

# %%
# !python aydao_flesh_digressions.py --pkl $pkl \
#                                    --psi=0.6 \
#                                    --radius_small=10.0 \
#                                    --radius_large=800.00
# !python aydao_flesh_digressions.py --pkl $pkl \
                                   --psi=0.6 \
                                   --radius_small=100 \
                                   --radius_large=200 \
                                   --seed 123456
# Out:
# Loading networks from "/mydrive/stylegan2-ada/results/00015-monixyp_tfrecords-11gb-gpu-bg-resumecustom/network-snapshot-000120.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Loading... Done.
# Stopping at 1.0 currently at 0.0025
# Stopping at 1.0 currently at 0.005
# Stopping at 1.0 currently at 0.0075
# Stopping at 1.0 currently at 0.01
# Stopping at 1.0 currently at 0.0125
# Stopping at 1.0 currently at 0.015000000000000001
# Stopping at 1.0 currently at 0.0175
# Stopping at 1.0 currently at 0.02
# Stopping at 1.0 currently at 0.0225
# Stopping at 1.0 currently at 0.024999999999999998
# Stopping at 1.0 currently at 0.027499999999999997
# Stopping at 1.0 currently at 0.029999999999999995
# Stopping at 1.0 currently at 0.032499999999999994
# Stopping at 1.0 currently at 0.034999999999999996
# Stopping at 1.0 currently at 0.0375
# Stopping at 1.0 currently at 0.04
# Stopping at 1.0 currently at 0.0425
# ...

# %%
# !python generate.py generate-images \
                    --outdir=out \
                    --trunc=1 \
                    --seeds=101-200 \
                    --network=/mydrive/stylegan2-ada/results/00015-monixyp_tfrecords-11gb-gpu-bg-resumecustom/network-snapshot-000120.pkl
# Out:
# Loading networks from "/mydrive/stylegan2-ada/results/00015-monixyp_tfrecords-11gb-gpu-bg-resumecustom/network-snapshot-000120.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Loading... Done.
# Generating image for seed 101 (0/100) ...
# Generating image for seed 102 (1/100) ...
# Generating image for seed 103 (2/100) ...
# Generating image for seed 104 (3/100) ...
# Generating image for seed 105 (4/100) ...
# Generating image for seed 106 (5/100) ...
# Generating image for seed 107 (6/100) ...
# Generating image for seed 108 (7/100) ...
# Generating image for seed 109 (8/100) ...
# Generating image for seed 110 (9/100) ...
# Generating image for seed 111 (10/100) ...
# Generating image for seed 112 (11/100) ...
# Generating image for seed 113 (12/100) ...
# Generating image for seed 114 (13/100) ...
# Generating image for seed 115 (14/100) ...
# Generating image for seed 116 (15/100) ...
# ...

# %%
# !python generate.py --help
# Out:
# usage: generate.py [-h]
#                    {generate-images,truncation-traversal,generate-latent-walk,generate-neighbors,lerp-video}
#                    ...
#
# Generate images using pretrained network pickle.
#
# positional arguments:
#   {generate-images,truncation-traversal,generate-latent-walk,generate-neighbors,lerp-video}
#                         Sub-commands
#     generate-images     Generate images
#     truncation-traversal
#                         Generate truncation walk
#     generate-latent-walk
#                         Generate latent walk
#     generate-neighbors  Generate random neighbors of a seed
#     lerp-video          Generate interpolation video (lerp) between random
#                         vectors
#
# optional arguments:
#   -h, --help            show this help message and exit
#
# examples:
#
#   # Generate curated MetFaces images without truncation (Fig.10 left)
#   python generate.py --outdir=out --trunc=1 --seeds=85,265,297,849 \
# ...

# %%
# !pip install opensimplex

# %%
# !python generate.py generate-latent-walk \
                    --outdir=out \
                    --network=/mydrive/stylegan2-ada/results/00015-monixyp_tfrecords-11gb-gpu-bg-resumecustom/network-snapshot-000120.pkl \
                    --seeds=24,34,111,146,197 \
                    --frames 200
# Out:
# Loading networks from "/mydrive/stylegan2-ada/results/00015-monixyp_tfrecords-11gb-gpu-bg-resumecustom/network-snapshot-000120.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Loading... Done.
# Generating image for step 0/204 ...
# Generating image for step 1/204 ...
# Generating image for step 2/204 ...
# Generating image for step 3/204 ...
# Generating image for step 4/204 ...
# Generating image for step 5/204 ...
# Generating image for step 6/204 ...
# Generating image for step 7/204 ...
# Generating image for step 8/204 ...
# Generating image for step 9/204 ...
# Generating image for step 10/204 ...
# Generating image for step 11/204 ...
# Generating image for step 12/204 ...
# Generating image for step 13/204 ...
# Generating image for step 14/204 ...
# Generating image for step 15/204 ...
# Generating image for step 16/204 ...
# Generating image for step 17/204 ...
# ...
