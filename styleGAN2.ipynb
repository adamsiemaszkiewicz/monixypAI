# %% [markdown]
# # Environment setup

# %% [markdown]
# ## Google Drive mount
# I'm using Google Colaboratory as my default platform, therefore I need to set up my environment to integrate it with Google Drive. You can skip this bit if you're working locally.
#
# 1. Mount Google Drive on the runtime to be able to read and write files. This will ask you to log in to your Google Account and provide an authorization code.
# 2. Create a symbolic link to a working directory
# 3. Change the directory to the one where I cloned my repository.

# %%
# mount Google Drive on the runtime
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# create a symbolic link to a working directory
# !ln -s /content/gdrive/My\ Drive/Colab\ Notebooks/SEJMograf /mydrive

# navigate to the working directory
# %cd /mydrive
# Out:
# /content/gdrive/My Drive/Colab Notebooks/SEJMograf

# %% [markdown]
# ## Libraries & functions
# Let's now import the necessary libraries and function we're gonna use in this notebook.

# %% [markdown]
# # StyleGAN2

# %%
# Out:
# TensorFlow 1.x selected.
# Cloning into 'stylegan2'...
# remote: Enumerating objects: 552, done.
# remote: Total 552 (delta 0), reused 0 (delta 0), pack-reused 552
# Receiving objects: 100% (552/552), 22.47 MiB | 8.87 MiB/s, done.
# Resolving deltas: 100% (285/285), done.
# Collecting opensimplex
#   Downloading https://files.pythonhosted.org/packages/9c/ad/9b758f9ff9dcd23fc574bb3aa1de844adb1179c9be9711e9f798614d4b2f/opensimplex-0.3-py3-none-any.whl
# Installing collected packages: opensimplex
# Successfully installed opensimplex-0.3
# /content/stylegan2

# %% [markdown]
# # References
# StyleGAN2-ADA Class: Week 1 https://www.youtube.com/watch?v=DVXX0tmVyco-
#
# https://www.youtube.com/watch?v=-6p0zwHc5-8
# https://www.youtube.com/watch?v=kbRkznsv9dk
# https://www.youtube.com/watch?v=CDbapbn-Nw4
# https://www.youtube.com/watch?v=ffesnWqknXI
# https://www.youtube.com/watch?v=VC9EROJEFwE
